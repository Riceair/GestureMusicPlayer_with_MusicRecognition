# %%
import numpy as np
import random
import cv2
import os

from tensorflow import keras
from keras.layers import *
from keras.models import *
from keras.optimizers import *

from keras.utils import np_utils
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score
import tensorflow as tf

# %% [markdown]
# ### 讀取頻譜圖路徑

# %%
mfcc_path = "ImageData/frameLen_40ms/mfcc" #original augmentation
spect_path = "ImageData/frameLen_40ms/spectrogram" #original augmentation
model_save_dir = "Model/ms_mfcc_model"
model_name = "MS_and_MFCC_40" #AUG
HIS_SHOW = False #是否show出訓練的history loss
epochs = 20
fold_num = 5
batch_size = 4
mfcc_folder_names = os.listdir(mfcc_path)
spect_folder_names = os.listdir(spect_path)
print(mfcc_folder_names, spect_folder_names)
# Out:
# ['Blue', 'Classical', 'Country', 'Disco', 'EDM', 'Hiphop', 'Jazz', 'Metal', 'Pop', 'Reggae'] ['Blue', 'Classical', 'Country', 'Disco', 'EDM', 'Hiphop', 'Jazz', 'Metal', 'Pop', 'Reggae']

# %%
folders=[] #儲存各類別資料夾中的檔案名稱
for folder in spect_folder_names:
    file_names=[]
    for file_name in os.listdir(spect_path+"/"+folder):
        file_names.append([spect_path+"/"+folder+"/"+file_name, mfcc_path+"/"+folder+"/"+file_name]) #加入mel 、mfcc路徑
    folders.append(file_names)

class_count_list = [len(files) for files in folders] #紀錄每個類別各有多少檔案(後面會用到)
print("class count: ", len(folders))
print("class file count: ", class_count_list)
# Out:
# class count:  10
# class file count:  [20, 20, 20, 20, 20, 20, 20, 20, 20, 20]

# %%
Data_names = []
for folder in folders:
    for names in folder:
        Data_names.append(names)
print(len(Data_names))
print(Data_names[0])
# Out:
# 200
# ['ImageData/frameLen_40ms/spectrogram/Blue/Blue000.png', 'ImageData/frameLen_40ms/mfcc/Blue/Blue000.png']

# %% [markdown]
# ### 製作Label

# %%
Label = []
for l, class_count in enumerate(class_count_list):
    for _ in range(class_count):
        Label.append(np.ones(1)*l)
Label = np.array(Label)

# %% [markdown]
# ### Data Generator定義

# %%
class DataGenerator:
    def __init__(self, data, label, batch_size=16):
        self.data = data
        self.label = label
        self.batch_size = batch_size
        self.steps = len(data)//self.batch_size
        if len(self.data) % self.batch_size != 0:
            self.steps += 1
    def __len__(self):
        return self.steps
    def __iter__(self):
        while True:
            #idxs = list(range(len(self.data)))
            #np.random.shuffle(idxs)
            X1, X2, Y = [], [], []
            for i in range(len(self.data)):
                name = self.data[i]
                x1 = cv2.imread(name[0]) #從路徑讀入spectogram和mfcc圖片
                x2 = cv2.imread(name[1])
                x1 = cv2.resize(x1, (224, 224))
                x2 = cv2.resize(x2, (224, 224))
                y = self.label[i]
                X1.append(x1)
                X2.append(x2)
                Y.append(y)
                if len(X1) == self.batch_size or i == len(self.data)-1:
                    X1 = np.array(X1)
                    X2 = np.array(X2)
                    Y = np.array(Y)
                    yield [X1, X2], Y
                    X1, X2, Y = [], [], []

# %% [markdown]
# ### 模型定義函數

# %%
def CONV(inputs):
    x = Conv2D(64, (7,3), activation='relu', padding = 'same')(inputs)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(128, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(256, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Flatten()(x)
    return x

# %%
def create_new_model():
    input_shape = (224, 224, 3)
    output_dim = len(folders)

    spect_inputs = Input(shape=input_shape)
    mfcc_inputs = Input(shape=input_shape)

    spect_outputs = CONV(spect_inputs)
    mfcc_outputs = CONV(mfcc_inputs)
    x = Concatenate()([spect_outputs, mfcc_outputs])
    
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(output_dim, activation='softmax')(x)

    model=Model([spect_inputs, mfcc_inputs],outputs)
    return model

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history, train, validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %% [markdown]
# ### 資料切割(Train and Test)

# %%
seed =  random.randint(0, 1000**2)
X_train_names, X_test_names, y_train, y_test = train_test_split(Data_names, Label, test_size=0.3,
                                                    random_state=seed, stratify = Label)
y_test_onehot = np_utils.to_categorical(y_test)

# %% [markdown]
# ### Stratified K-fold

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TEST_ACCURACY=[]

skf = StratifiedKFold(n_splits=fold_num)
fold_var = 1

for train_index, valid_index in skf.split(X_train_names, y_train):
    
    #準備該次的train data(路徑)
    X_train_name_fold = []
    for idx in train_index:
        X_train_name_fold.append(X_train_names[idx])
    y_train_fold = y_train[train_index]
    y_train_fold_onehot = np_utils.to_categorical(y_train_fold)

    X_val_name_fold = []
    for idx in valid_index:
        X_val_name_fold.append(X_train_names[idx])
    y_val_fold = y_train[valid_index]
    y_val_fold_onehot = np_utils.to_categorical(y_val_fold)
    
    train_D = DataGenerator(X_train_name_fold, y_train_fold_onehot, batch_size)
    valid_D = DataGenerator(X_val_name_fold, y_val_fold_onehot, batch_size)
    
    model = create_new_model()
    opt = adam_v2.Adam(learning_rate=0.0001)
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy'])
    # CREATE CALLBACKS
    checkpoint = tf.keras.callbacks.ModelCheckpoint(model_save_dir+"/"+model_name+"_fold"+str(fold_var)+".h5",
                                    monitor='val_accuracy', 
                                    save_best_only=True)
    callbacks_list = [checkpoint]
    
    history = model.fit(
                    train_D.__iter__(),
                    steps_per_epoch = train_D.__len__(),
                    validation_data=valid_D.__iter__(),
                    validation_steps=valid_D.__len__(),
                    epochs=epochs,
                    callbacks=callbacks_list,
                    verbose=1) # 訓練紀錄顯示
    if HIS_SHOW:
        show_train_history(history, 'loss', 'val_loss')
    
    model.load_weights(model_save_dir+"/"+model_name+"_fold"+str(fold_var)+".h5")
    results = model.evaluate(valid_D.__iter__(), steps=valid_D.__len__(), verbose=1)
    results = dict(zip(model.metrics_names,results))
    
    VALIDATION_ACCURACY.append(results['accuracy'])
    VALIDATION_LOSS.append(results['loss'])
    
    test_D = DataGenerator(X_test_names, y_test_onehot, batch_size)
    scores = model.evaluate(test_D.__iter__(), steps=test_D.__len__(), verbose=0)
    print(str(fold_var)+" Fold: "+"Accuracy of testing data = {:2.2f}%".format(scores[1]*100.0))
    print()
    TEST_ACCURACY.append(scores[1]*100.0)
    
    tf.keras.backend.clear_session()
    fold_var+=1
    #break
# Out:
# Epoch 1/20
# 28/28 [==============================] - 10s 210ms/step - loss: 46.6118 - accuracy: 0.1204 - val_loss: 2.7192 - val_accuracy: 0.2500
# Epoch 2/20
# 28/28 [==============================] - 4s 144ms/step - loss: 2.6437 - accuracy: 0.2330 - val_loss: 1.9583 - val_accuracy: 0.3214
# Epoch 3/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.7822 - accuracy: 0.3120 - val_loss: 1.9598 - val_accuracy: 0.3571
# Epoch 4/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.5549 - accuracy: 0.4470 - val_loss: 1.7738 - val_accuracy: 0.4286
# Epoch 5/20
# 28/28 [==============================] - 4s 146ms/step - loss: 1.2787 - accuracy: 0.5653 - val_loss: 1.7608 - val_accuracy: 0.3571
# Epoch 6/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.1062 - accuracy: 0.5947 - val_loss: 1.8789 - val_accuracy: 0.5000
# Epoch 7/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.0615 - accuracy: 0.6513 - val_loss: 1.6690 - val_accuracy: 0.5000
# Epoch 8/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.9693 - accuracy: 0.6485 - val_loss: 1.5521 - val_accuracy: 0.6071
# Epoch 9/20
# 28/28 [==============================] - 4s 147ms/step - loss: 0.7044 - accuracy: 0.7062 - val_loss: 1.6623 - val_accuracy: 0.5000
# Epoch 10/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.4891 - accuracy: 0.8673 - val_loss: 1.7171 - val_accuracy: 0.6071
# Epoch 11/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.5784 - accuracy: 0.7925 - val_loss: 1.7325 - val_accuracy: 0.5357
# Epoch 12/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.3817 - accuracy: 0.8873 - val_loss: 2.2144 - val_accuracy: 0.4643
# Epoch 13/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.3111 - accuracy: 0.8970 - val_loss: 3.5113 - val_accuracy: 0.3214
# Epoch 14/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.2835 - accuracy: 0.8869 - val_loss: 1.7611 - val_accuracy: 0.6071
# Epoch 15/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.3335 - accuracy: 0.8871 - val_loss: 1.8240 - val_accuracy: 0.4643
# Epoch 16/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.1556 - accuracy: 0.9414 - val_loss: 1.7379 - val_accuracy: 0.6786
# Epoch 17/20
# 28/28 [==============================] - 4s 155ms/step - loss: 0.1478 - accuracy: 0.9467 - val_loss: 3.2276 - val_accuracy: 0.4643
# Epoch 18/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.6482 - accuracy: 0.8387 - val_loss: 1.8666 - val_accuracy: 0.6071
# Epoch 19/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.0837 - accuracy: 0.9703 - val_loss: 2.2335 - val_accuracy: 0.6429
# Epoch 20/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.2404 - accuracy: 0.9158 - val_loss: 1.9061 - val_accuracy: 0.5000
# 7/7 [==============================] - 0s 30ms/step - loss: 1.7379 - accuracy: 0.6786
# 1 Fold: Accuracy of testing data = 53.33%
#
# Epoch 1/20
# 28/28 [==============================] - 5s 153ms/step - loss: 55.8760 - accuracy: 0.1189 - val_loss: 2.4725 - val_accuracy: 0.1429
# Epoch 2/20
# 28/28 [==============================] - 4s 146ms/step - loss: 2.2690 - accuracy: 0.2964 - val_loss: 1.8464 - val_accuracy: 0.2857
# Epoch 3/20
# 28/28 [==============================] - 4s 146ms/step - loss: 1.7321 - accuracy: 0.3920 - val_loss: 1.5066 - val_accuracy: 0.5000
# Epoch 4/20
# 28/28 [==============================] - 4s 155ms/step - loss: 1.3335 - accuracy: 0.6435 - val_loss: 1.3204 - val_accuracy: 0.5357
# Epoch 5/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.0204 - accuracy: 0.6833 - val_loss: 1.2279 - val_accuracy: 0.5714
# Epoch 6/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.6751 - accuracy: 0.7862 - val_loss: 1.3913 - val_accuracy: 0.5000
# Epoch 7/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.4911 - accuracy: 0.8864 - val_loss: 1.5003 - val_accuracy: 0.5357
# Epoch 8/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.3540 - accuracy: 0.9192 - val_loss: 1.9563 - val_accuracy: 0.3929
# Epoch 9/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.3904 - accuracy: 0.8697 - val_loss: 1.8958 - val_accuracy: 0.5000
# Epoch 10/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.4413 - accuracy: 0.8845 - val_loss: 2.1301 - val_accuracy: 0.4643
# Epoch 11/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.6782 - accuracy: 0.8726 - val_loss: 1.5362 - val_accuracy: 0.3929
# Epoch 12/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.3696 - accuracy: 0.8695 - val_loss: 1.3831 - val_accuracy: 0.5357
# Epoch 13/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.2301 - accuracy: 0.9716 - val_loss: 1.9439 - val_accuracy: 0.4286
# Epoch 14/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.2932 - accuracy: 0.9728 - val_loss: 1.2640 - val_accuracy: 0.5714
# Epoch 15/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.1241 - accuracy: 0.9728 - val_loss: 1.3451 - val_accuracy: 0.6071
# Epoch 16/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.1121 - accuracy: 0.9654 - val_loss: 1.2190 - val_accuracy: 0.6071
# Epoch 17/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.0613 - accuracy: 0.9728 - val_loss: 1.1338 - val_accuracy: 0.6429
# Epoch 18/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.0842 - accuracy: 0.9728 - val_loss: 1.0199 - val_accuracy: 0.7143
# Epoch 19/20
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0470 - accuracy: 0.9728 - val_loss: 1.0255 - val_accuracy: 0.7143
# Epoch 20/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.0603 - accuracy: 0.9728 - val_loss: 1.0298 - val_accuracy: 0.6786
# 7/7 [==============================] - 0s 30ms/step - loss: 1.0199 - accuracy: 0.7143
# 2 Fold: Accuracy of testing data = 51.67%
#
# Epoch 1/20
# 28/28 [==============================] - 5s 153ms/step - loss: 62.7457 - accuracy: 0.1425 - val_loss: 2.2392 - val_accuracy: 0.2143
# Epoch 2/20
# 28/28 [==============================] - 4s 145ms/step - loss: 2.4102 - accuracy: 0.1691 - val_loss: 1.9861 - val_accuracy: 0.3214
# Epoch 3/20
# 28/28 [==============================] - 4s 147ms/step - loss: 1.9599 - accuracy: 0.2840 - val_loss: 1.7342 - val_accuracy: 0.2857
# Epoch 4/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.7458 - accuracy: 0.3632 - val_loss: 1.6354 - val_accuracy: 0.3214
# Epoch 5/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.5175 - accuracy: 0.5313 - val_loss: 1.5679 - val_accuracy: 0.6071
# Epoch 6/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.3345 - accuracy: 0.4852 - val_loss: 1.6394 - val_accuracy: 0.3571
# Epoch 7/20
# 28/28 [==============================] - 4s 146ms/step - loss: 1.1938 - accuracy: 0.5833 - val_loss: 1.7942 - val_accuracy: 0.3929
# Epoch 8/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.2262 - accuracy: 0.5549 - val_loss: 1.4402 - val_accuracy: 0.5000
# Epoch 9/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.8318 - accuracy: 0.6966 - val_loss: 1.4886 - val_accuracy: 0.5357
# Epoch 10/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.6522 - accuracy: 0.8481 - val_loss: 1.4832 - val_accuracy: 0.5357
# Epoch 11/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.5105 - accuracy: 0.8403 - val_loss: 1.7846 - val_accuracy: 0.5000
# Epoch 12/20
# 28/28 [==============================] - 4s 148ms/step - loss: 0.4288 - accuracy: 0.8883 - val_loss: 1.4771 - val_accuracy: 0.5000
# Epoch 13/20
# 28/28 [==============================] - 4s 148ms/step - loss: 0.3301 - accuracy: 0.9170 - val_loss: 2.0537 - val_accuracy: 0.5000
# Epoch 14/20
# 28/28 [==============================] - 4s 150ms/step - loss: 0.3511 - accuracy: 0.9113 - val_loss: 1.7255 - val_accuracy: 0.5000
# Epoch 15/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.2590 - accuracy: 0.9368 - val_loss: 2.1347 - val_accuracy: 0.4286
# Epoch 16/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.4318 - accuracy: 0.8962 - val_loss: 1.8392 - val_accuracy: 0.5000
# Epoch 17/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.2654 - accuracy: 0.9410 - val_loss: 2.0000 - val_accuracy: 0.5357
# Epoch 18/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.5032 - accuracy: 0.8098 - val_loss: 1.8369 - val_accuracy: 0.5357
# Epoch 19/20
# 28/28 [==============================] - 4s 147ms/step - loss: 0.3199 - accuracy: 0.9131 - val_loss: 1.4560 - val_accuracy: 0.6071
# Epoch 20/20
# 28/28 [==============================] - 4s 147ms/step - loss: 0.1866 - accuracy: 0.9225 - val_loss: 1.7326 - val_accuracy: 0.4643
# 7/7 [==============================] - 0s 33ms/step - loss: 1.5679 - accuracy: 0.6071
# 3 Fold: Accuracy of testing data = 41.67%
#
# Epoch 1/20
# 28/28 [==============================] - 5s 158ms/step - loss: 54.7700 - accuracy: 0.1260 - val_loss: 2.7663 - val_accuracy: 0.2143
# Epoch 2/20
# 28/28 [==============================] - 4s 151ms/step - loss: 2.3306 - accuracy: 0.2172 - val_loss: 2.7518 - val_accuracy: 0.2857
# Epoch 3/20
# 28/28 [==============================] - 4s 150ms/step - loss: 1.9578 - accuracy: 0.2460 - val_loss: 2.6657 - val_accuracy: 0.3571
# Epoch 4/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.7211 - accuracy: 0.3683 - val_loss: 2.5152 - val_accuracy: 0.3929
# Epoch 5/20
# 28/28 [==============================] - 4s 146ms/step - loss: 1.5576 - accuracy: 0.4987 - val_loss: 2.4043 - val_accuracy: 0.3571
# Epoch 6/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.3868 - accuracy: 0.5521 - val_loss: 2.2595 - val_accuracy: 0.3929
# Epoch 7/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.1930 - accuracy: 0.5840 - val_loss: 2.1122 - val_accuracy: 0.6071
# Epoch 8/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.0248 - accuracy: 0.6773 - val_loss: 3.0008 - val_accuracy: 0.4643
# Epoch 9/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.6852 - accuracy: 0.8215 - val_loss: 2.1882 - val_accuracy: 0.5714
# Epoch 10/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.4380 - accuracy: 0.8783 - val_loss: 2.5280 - val_accuracy: 0.5357
# Epoch 11/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.3225 - accuracy: 0.9281 - val_loss: 3.1181 - val_accuracy: 0.5000
# Epoch 12/20
# 28/28 [==============================] - 4s 144ms/step - loss: 0.1898 - accuracy: 0.9397 - val_loss: 3.2182 - val_accuracy: 0.4643
# Epoch 13/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.2019 - accuracy: 0.9557 - val_loss: 3.1651 - val_accuracy: 0.5714
# Epoch 14/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.1719 - accuracy: 0.9839 - val_loss: 3.1157 - val_accuracy: 0.5000
# Epoch 15/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.2133 - accuracy: 0.9093 - val_loss: 3.3778 - val_accuracy: 0.4643
# Epoch 16/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.1306 - accuracy: 0.9578 - val_loss: 3.3572 - val_accuracy: 0.4286
# Epoch 17/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.0662 - accuracy: 0.9935 - val_loss: 3.7319 - val_accuracy: 0.5357
# Epoch 18/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.2168 - accuracy: 0.9447 - val_loss: 4.2756 - val_accuracy: 0.5000
# Epoch 19/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 3.2922 - val_accuracy: 0.4643
# Epoch 20/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 3.4603 - val_accuracy: 0.5000
# 7/7 [==============================] - 0s 31ms/step - loss: 2.1122 - accuracy: 0.6071
# 4 Fold: Accuracy of testing data = 50.00%
#
# Epoch 1/20
# 28/28 [==============================] - 6s 155ms/step - loss: 45.9856 - accuracy: 0.1102 - val_loss: 2.7112 - val_accuracy: 0.3214
# Epoch 2/20
# 28/28 [==============================] - 4s 145ms/step - loss: 2.7413 - accuracy: 0.1643 - val_loss: 2.0006 - val_accuracy: 0.3214
# Epoch 3/20
# 28/28 [==============================] - 4s 145ms/step - loss: 2.2071 - accuracy: 0.2240 - val_loss: 1.9164 - val_accuracy: 0.3571
# Epoch 4/20
# 28/28 [==============================] - 4s 148ms/step - loss: 2.0200 - accuracy: 0.3003 - val_loss: 1.8390 - val_accuracy: 0.2857
# Epoch 5/20
# 28/28 [==============================] - 4s 146ms/step - loss: 1.7008 - accuracy: 0.3974 - val_loss: 1.6973 - val_accuracy: 0.3929
# Epoch 6/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.4048 - accuracy: 0.5110 - val_loss: 1.9832 - val_accuracy: 0.2857
# Epoch 7/20
# 28/28 [==============================] - 4s 145ms/step - loss: 1.0890 - accuracy: 0.6288 - val_loss: 1.2001 - val_accuracy: 0.4643
# Epoch 8/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.6411 - accuracy: 0.8127 - val_loss: 1.3150 - val_accuracy: 0.4643
# Epoch 9/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.5617 - accuracy: 0.8344 - val_loss: 2.6601 - val_accuracy: 0.3571
# Epoch 10/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.8646 - accuracy: 0.6957 - val_loss: 1.6763 - val_accuracy: 0.4643
# Epoch 11/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.5259 - accuracy: 0.7722 - val_loss: 2.2672 - val_accuracy: 0.3929
# Epoch 12/20
# 28/28 [==============================] - 4s 152ms/step - loss: 0.3091 - accuracy: 0.9005 - val_loss: 2.0920 - val_accuracy: 0.4643
# Epoch 13/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.3728 - accuracy: 0.9013 - val_loss: 1.2384 - val_accuracy: 0.5357
# Epoch 14/20
# 28/28 [==============================] - 4s 148ms/step - loss: 0.1884 - accuracy: 0.9634 - val_loss: 2.2809 - val_accuracy: 0.5357
# Epoch 15/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.4463 - accuracy: 0.9260 - val_loss: 2.0083 - val_accuracy: 0.3571
# Epoch 16/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.1838 - accuracy: 0.9555 - val_loss: 1.4609 - val_accuracy: 0.6071
# Epoch 17/20
# 28/28 [==============================] - 4s 147ms/step - loss: 0.1466 - accuracy: 0.9578 - val_loss: 1.7058 - val_accuracy: 0.5000
# Epoch 18/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.2206 - accuracy: 0.9282 - val_loss: 1.2123 - val_accuracy: 0.5714
# Epoch 19/20
# 28/28 [==============================] - 4s 146ms/step - loss: 0.0767 - accuracy: 0.9738 - val_loss: 1.3358 - val_accuracy: 0.6071
# Epoch 20/20
# 28/28 [==============================] - 4s 145ms/step - loss: 0.0616 - accuracy: 0.9738 - val_loss: 1.6026 - val_accuracy: 0.6429
# 7/7 [==============================] - 0s 32ms/step - loss: 1.6026 - accuracy: 0.6429
# 5 Fold: Accuracy of testing data = 61.67%

# %%
print("validation accuracy: ",VALIDATION_ACCURACY)
print("validation loss: ", VALIDATION_LOSS)
print("test accuracy: ",TEST_ACCURACY)
# Out:
# validation accuracy:  [0.6785714030265808, 0.7142857313156128, 0.6071428656578064, 0.6071428656578064, 0.6428571343421936]
# validation loss:  [1.7378708124160767, 1.0199177265167236, 1.5679441690444946, 2.11220645904541, 1.6025904417037964]
# test accuracy:  [53.33333611488342, 51.66666507720947, 41.66666567325592, 50.0, 61.666667461395264]

# %%
print("average validation accuracy: ",sum(VALIDATION_ACCURACY)/len(VALIDATION_ACCURACY))
print("average test accuracy: ",sum(TEST_ACCURACY)/len(TEST_ACCURACY))
# Out:
# average validation accuracy:  0.65
# average test accuracy:  51.666666865348816
