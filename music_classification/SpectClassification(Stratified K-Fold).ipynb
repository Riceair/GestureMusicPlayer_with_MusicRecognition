# %%
import numpy as np
import random
import cv2
import os

from tensorflow import keras
from keras.layers import *
from keras.models import *
from keras.optimizers import *

from keras.utils import np_utils
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score
import tensorflow as tf

# %% [markdown]
# ### 讀取頻譜圖路徑

# %%
INPUT_SELECT = 0 #決定模型的輸入 0: log mel scale spectrogram, 1: mfcc
CNN_SELECT = 1 #決定CNN的類型 0: VGG16, 1: 自訂義CNN
IS_AUG=False
HIS_SHOW = False #是否show出訓練的history loss
epochs = 20
batch_size = 4
fold_num = 10
MODEL_DIR = ("Model/ms_model", "Model/mfcc_model")
MODEL_NAME = ("MS", "MFCC", "MS_AUG", "MFCC_AUG")
IMG_PATH = ("ImageData/original/spectrogram", "ImageData/original/mfcc",
                        "ImageData/augmentation/spectrogram", "ImageData/original/mfcc")

# %%
if IS_AUG:
    AUG=2
else:
    AUG=0
root_path = IMG_PATH[INPUT_SELECT+AUG]
model_save_dir = MODEL_DIR[INPUT_SELECT]
model_name = MODEL_NAME[INPUT_SELECT+AUG]
folder_names = os.listdir(root_path)
print(root_path, folder_names)
# Out:
# ImageData/original/spectrogram ['Blue', 'Classical', 'Country', 'Disco', 'EDM', 'Hiphop', 'Jazz', 'Metal', 'Pop', 'Reggae']

# %%
folders=[] #儲存各類別資料夾中的檔案名稱
for folder in folder_names:
    file_names=[]
    for file_name in os.listdir(root_path+"/"+folder):
        file_names.append(root_path+"/"+folder+"/"+file_name)
    folders.append(file_names)

class_count_list = [len(files) for files in folders] #紀錄每個類別各有多少檔案(後面會用到)
print("class count: ", len(folders))
print("class file count: ", class_count_list)
# Out:
# class count:  10
# class file count:  [20, 20, 20, 20, 20, 20, 20, 20, 20, 20]

# %% [markdown]
# ### 讀取頻譜圖

# %%
Data = []
for folder in folders:
    for name in folder:
        spect = cv2.imread(name) #shape=(220, 449, 3)
        spect = cv2.resize(spect, (224, 224))
#         spect = cv2.cvtColor(spect, cv2.COLOR_BGR2GRAY) #轉灰階
#         spect = spect.T #轉置
        Data.append(spect)
Data = np.array(Data)

# %%
Data.shape
# Out:
# (200, 224, 224, 3)

# %% [markdown]
# ### 製作Label

# %%
Label = []
for l, class_count in enumerate(class_count_list):
    for _ in range(class_count):
        Label.append(np.ones(1)*l)
Label = np.array(Label)

# %% [markdown]
# ### CNN層定義

# %%
def VGG16(inputs):
    x = Conv2D(64, (3,3), activation='relu', padding = 'same')(inputs)
    x = Dropout(0.03)(x)
    x = Conv2D(64, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(128, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = Conv2D(128, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(256, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = Conv2D(256, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = Conv2D(256, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Flatten()(x)
    return x

# %%
def CONV(inputs):
    x = Conv2D(64, (7,3), activation='relu', padding = 'same')(inputs)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(128, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(256, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(512, (3,3), activation='relu', padding = 'same')(x)
    x = Dropout(0.03)(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Flatten()(x)
    return x

# %%
def create_new_model(data, cnn_selection):
    input_shape = data.shape
    output_dim = len(folders)

    inputs = Input(shape=input_shape)
    
    if cnn_selection == 0:
        x = VGG16(inputs)
    else:
        x = CONV(inputs)
    x = Dense(512, activation='relu')(x)
    x = Dense(256, activation='relu')(x)
    outputs = Dense(output_dim, activation='softmax')(x)

    model=Model(inputs,outputs)
    return model

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history, train, validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %% [markdown]
# ### 資料切割(Train and Test)

# %%
seed =  random.randint(0, 1000**2)
X_train, X_test, y_train, y_test = train_test_split(Data, Label, test_size=0.3,
                                                    random_state=seed, stratify = Label)
y_test_onehot = np_utils.to_categorical(y_test)

# %% [markdown]
# ### Stratified K-fold

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TEST_ACCURACY=[]

skf = StratifiedKFold(n_splits=fold_num)
fold_var = 1

for train_index, valid_index in skf.split(X_train, y_train):
    X_train_fold = X_train[train_index]
    y_train_fold = y_train[train_index]
    y_train_fold_onehot = np_utils.to_categorical(y_train_fold)
    
    X_val_fold = X_train[valid_index]
    y_val_fold = y_train[valid_index]
    y_val_fold_onehot = np_utils.to_categorical(y_val_fold)
    
    model = create_new_model(X_train_fold[0], CNN_SELECT)
    opt = Adam(lr=0.0001)
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy'])
    # CREATE CALLBACKS
    checkpoint = tf.keras.callbacks.ModelCheckpoint(model_save_dir+"/"+model_name+"_fold"+str(fold_var)+".h5",
                                    monitor='val_accuracy', 
                                    save_best_only=True)
    callbacks_list = [checkpoint]
    
    history = model.fit(x=X_train_fold, y=y_train_fold_onehot,
                    validation_data=(X_val_fold, y_val_fold_onehot),
                    epochs=epochs, batch_size=batch_size,
                    callbacks=callbacks_list,
                    verbose=1) # 訓練紀錄顯示
    
    model.load_weights(model_save_dir+"/"+model_name+"_fold"+str(fold_var)+".h5")
    if HIS_SHOW:
        show_train_history(history, 'loss', 'val_loss')
    
    results = model.evaluate(X_val_fold, y_val_fold_onehot, batch_size=8, verbose=0)
    results = dict(zip(model.metrics_names,results))
    
    VALIDATION_ACCURACY.append(results['accuracy'])
    VALIDATION_LOSS.append(results['loss'])
    
    
    scores = model.evaluate(X_test, y_test_onehot, batch_size=8, verbose=0)
    print(str(fold_var)+" Fold: "+"Accuracy of testing data = {:2.2f}%".format(scores[1]*100.0))
    print()
    TEST_ACCURACY.append(scores[1]*100.0)
    
    tf.keras.backend.clear_session()
    fold_var+=1
# Out:
# Epoch 1/20
# 32/32 [==============================] - 8s 142ms/step - loss: 32.5514 - accuracy: 0.0816 - val_loss: 2.2108 - val_accuracy: 0.1429
# Epoch 2/20
# 32/32 [==============================] - 3s 93ms/step - loss: 2.1029 - accuracy: 0.2204 - val_loss: 1.9896 - val_accuracy: 0.2143
# Epoch 3/20
# 32/32 [==============================] - 3s 92ms/step - loss: 1.6032 - accuracy: 0.4457 - val_loss: 1.6988 - val_accuracy: 0.4286
# Epoch 4/20
# 32/32 [==============================] - 3s 89ms/step - loss: 1.3434 - accuracy: 0.5556 - val_loss: 1.6655 - val_accuracy: 0.3571
# Epoch 5/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.9335 - accuracy: 0.7561 - val_loss: 1.6125 - val_accuracy: 0.5714
# Epoch 6/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.6215 - accuracy: 0.8056 - val_loss: 1.6917 - val_accuracy: 0.4286
# Epoch 7/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.5600 - accuracy: 0.8563 - val_loss: 2.5884 - val_accuracy: 0.5000
# Epoch 8/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3636 - accuracy: 0.8708 - val_loss: 1.9840 - val_accuracy: 0.3571
# Epoch 9/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.5671 - accuracy: 0.8719 - val_loss: 1.8477 - val_accuracy: 0.3571
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1494 - accuracy: 0.9742 - val_loss: 2.2641 - val_accuracy: 0.3571
# Epoch 11/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2606 - accuracy: 0.9171 - val_loss: 1.6892 - val_accuracy: 0.6429
# Epoch 12/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.0515 - accuracy: 0.9964 - val_loss: 1.7096 - val_accuracy: 0.4286
# Epoch 13/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1089 - accuracy: 0.9792 - val_loss: 1.8218 - val_accuracy: 0.5000
# Epoch 14/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0355 - accuracy: 0.9919 - val_loss: 1.9577 - val_accuracy: 0.5000
# Epoch 15/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0334 - accuracy: 0.9900 - val_loss: 1.9926 - val_accuracy: 0.5000
# Epoch 16/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0765 - accuracy: 0.9712 - val_loss: 1.5572 - val_accuracy: 0.5714
# Epoch 17/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0305 - accuracy: 0.9849 - val_loss: 1.7455 - val_accuracy: 0.5000
# Epoch 18/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2493 - accuracy: 0.9436 - val_loss: 1.7514 - val_accuracy: 0.5000
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0330 - accuracy: 0.9979 - val_loss: 2.0851 - val_accuracy: 0.4286
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0425 - accuracy: 0.9824 - val_loss: 1.9042 - val_accuracy: 0.4286
# 1 Fold: Accuracy of testing data = 61.67%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 91ms/step - loss: 53.3270 - accuracy: 0.1258 - val_loss: 2.3292 - val_accuracy: 0.2143
# Epoch 2/20
# 32/32 [==============================] - 3s 85ms/step - loss: 2.1929 - accuracy: 0.1994 - val_loss: 2.0182 - val_accuracy: 0.2857
# Epoch 3/20
# 32/32 [==============================] - 3s 90ms/step - loss: 2.0428 - accuracy: 0.1538 - val_loss: 2.0038 - val_accuracy: 0.2143
# Epoch 4/20
# 32/32 [==============================] - 3s 90ms/step - loss: 1.8444 - accuracy: 0.3142 - val_loss: 2.0291 - val_accuracy: 0.2857
# Epoch 5/20
# 32/32 [==============================] - 3s 88ms/step - loss: 1.7293 - accuracy: 0.4017 - val_loss: 1.6599 - val_accuracy: 0.3571
# Epoch 6/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.4175 - accuracy: 0.4986 - val_loss: 1.7383 - val_accuracy: 0.3571
# Epoch 7/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.1428 - accuracy: 0.5908 - val_loss: 1.7749 - val_accuracy: 0.2143
# Epoch 8/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.0068 - accuracy: 0.6967 - val_loss: 1.9270 - val_accuracy: 0.3571
# Epoch 9/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.8339 - accuracy: 0.7804 - val_loss: 1.6049 - val_accuracy: 0.4286
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.5806 - accuracy: 0.8257 - val_loss: 1.0925 - val_accuracy: 0.7143
# Epoch 11/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.8661 - accuracy: 0.7979 - val_loss: 1.0842 - val_accuracy: 0.7143
# Epoch 12/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.3117 - accuracy: 0.9190 - val_loss: 1.2883 - val_accuracy: 0.5714
# Epoch 13/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.2933 - accuracy: 0.9161 - val_loss: 1.1141 - val_accuracy: 0.7143
# Epoch 14/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.3292 - accuracy: 0.8834 - val_loss: 1.0853 - val_accuracy: 0.6429
# Epoch 15/20
# 32/32 [==============================] - 3s 92ms/step - loss: 0.2768 - accuracy: 0.8998 - val_loss: 1.4929 - val_accuracy: 0.6429
# Epoch 16/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0904 - accuracy: 0.9829 - val_loss: 1.4480 - val_accuracy: 0.5000
# Epoch 17/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0499 - accuracy: 0.9804 - val_loss: 2.2346 - val_accuracy: 0.5000
# Epoch 18/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.1114 - accuracy: 0.9732 - val_loss: 1.7649 - val_accuracy: 0.5714
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2659 - accuracy: 0.9275 - val_loss: 1.1942 - val_accuracy: 0.7143
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0765 - accuracy: 0.9689 - val_loss: 1.4263 - val_accuracy: 0.6429
# 2 Fold: Accuracy of testing data = 60.00%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 91ms/step - loss: 47.7435 - accuracy: 0.1462 - val_loss: 2.4196 - val_accuracy: 0.2143
# Epoch 2/20
# 32/32 [==============================] - 3s 85ms/step - loss: 2.1109 - accuracy: 0.2778 - val_loss: 2.3084 - val_accuracy: 0.1429
# Epoch 3/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.7951 - accuracy: 0.4352 - val_loss: 2.0769 - val_accuracy: 0.2143
# Epoch 4/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.5745 - accuracy: 0.3889 - val_loss: 2.1719 - val_accuracy: 0.2857
# Epoch 5/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.3879 - accuracy: 0.5856 - val_loss: 2.3203 - val_accuracy: 0.3571
# Epoch 6/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.2134 - accuracy: 0.6312 - val_loss: 1.9326 - val_accuracy: 0.2857
# Epoch 7/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.9334 - accuracy: 0.6832 - val_loss: 1.8834 - val_accuracy: 0.4286
# Epoch 8/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.8995 - accuracy: 0.7391 - val_loss: 1.5808 - val_accuracy: 0.3571
# Epoch 9/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.6591 - accuracy: 0.8215 - val_loss: 1.4858 - val_accuracy: 0.5714
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4327 - accuracy: 0.8636 - val_loss: 2.1694 - val_accuracy: 0.2857
# Epoch 11/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.6168 - accuracy: 0.7365 - val_loss: 1.3867 - val_accuracy: 0.5000
# Epoch 12/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3646 - accuracy: 0.8880 - val_loss: 1.5625 - val_accuracy: 0.5714
# Epoch 13/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.3256 - accuracy: 0.8862 - val_loss: 1.6421 - val_accuracy: 0.5000
# Epoch 14/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2589 - accuracy: 0.9070 - val_loss: 1.4902 - val_accuracy: 0.5714
# Epoch 15/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1225 - accuracy: 0.9672 - val_loss: 1.7435 - val_accuracy: 0.6429
# Epoch 16/20
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0571 - accuracy: 0.9943 - val_loss: 2.1976 - val_accuracy: 0.5714
# Epoch 17/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1772 - accuracy: 0.9800 - val_loss: 1.6592 - val_accuracy: 0.3571
# Epoch 18/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0411 - accuracy: 0.9995 - val_loss: 1.5542 - val_accuracy: 0.7143
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0621 - accuracy: 0.9924 - val_loss: 1.5458 - val_accuracy: 0.5000
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0277 - accuracy: 0.9980 - val_loss: 1.7301 - val_accuracy: 0.6429
# 3 Fold: Accuracy of testing data = 63.33%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 92ms/step - loss: 35.0889 - accuracy: 0.1660 - val_loss: 2.2035 - val_accuracy: 0.2143
# Epoch 2/20
# 32/32 [==============================] - 3s 84ms/step - loss: 2.0446 - accuracy: 0.2298 - val_loss: 1.9438 - val_accuracy: 0.3571
# Epoch 3/20
# 32/32 [==============================] - 3s 84ms/step - loss: 1.8348 - accuracy: 0.3554 - val_loss: 1.8002 - val_accuracy: 0.4286
# Epoch 4/20
# 32/32 [==============================] - 3s 89ms/step - loss: 1.6611 - accuracy: 0.4031 - val_loss: 1.4070 - val_accuracy: 0.5714
# Epoch 5/20
# 32/32 [==============================] - 3s 89ms/step - loss: 1.3410 - accuracy: 0.5044 - val_loss: 1.4930 - val_accuracy: 0.2857
# Epoch 6/20
# 32/32 [==============================] - 3s 90ms/step - loss: 1.0180 - accuracy: 0.6881 - val_loss: 1.3927 - val_accuracy: 0.5714
# Epoch 7/20
# 32/32 [==============================] - 3s 90ms/step - loss: 0.9200 - accuracy: 0.6364 - val_loss: 1.2368 - val_accuracy: 0.5714
# Epoch 8/20
# 32/32 [==============================] - 3s 90ms/step - loss: 0.5768 - accuracy: 0.8585 - val_loss: 1.7659 - val_accuracy: 0.3571
# Epoch 9/20
# 32/32 [==============================] - 3s 90ms/step - loss: 0.5362 - accuracy: 0.8210 - val_loss: 1.5184 - val_accuracy: 0.4286
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.6803 - accuracy: 0.7662 - val_loss: 1.1111 - val_accuracy: 0.5714
# Epoch 11/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3875 - accuracy: 0.8752 - val_loss: 1.6096 - val_accuracy: 0.5714
# Epoch 12/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2591 - accuracy: 0.9220 - val_loss: 1.2116 - val_accuracy: 0.5714
# Epoch 13/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1839 - accuracy: 0.9398 - val_loss: 2.0315 - val_accuracy: 0.3571
# Epoch 14/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1918 - accuracy: 0.9269 - val_loss: 1.6164 - val_accuracy: 0.5000
# Epoch 15/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1522 - accuracy: 0.9398 - val_loss: 1.1005 - val_accuracy: 0.5000
# Epoch 16/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0468 - accuracy: 0.9969 - val_loss: 1.4929 - val_accuracy: 0.5000
# Epoch 17/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0463 - accuracy: 0.9888 - val_loss: 2.4113 - val_accuracy: 0.4286
# Epoch 18/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1683 - accuracy: 0.9636 - val_loss: 1.5960 - val_accuracy: 0.5000
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0921 - accuracy: 0.9908 - val_loss: 1.5456 - val_accuracy: 0.5000
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0404 - accuracy: 0.9866 - val_loss: 1.5874 - val_accuracy: 0.4286
# 4 Fold: Accuracy of testing data = 41.67%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 91ms/step - loss: 25.1379 - accuracy: 0.1418 - val_loss: 2.6861 - val_accuracy: 0.2857
# Epoch 2/20
# 32/32 [==============================] - 3s 85ms/step - loss: 2.2969 - accuracy: 0.2607 - val_loss: 2.0775 - val_accuracy: 0.2143
# Epoch 3/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.8574 - accuracy: 0.3304 - val_loss: 1.7717 - val_accuracy: 0.5000
# Epoch 4/20
# 32/32 [==============================] - 3s 90ms/step - loss: 1.4090 - accuracy: 0.5031 - val_loss: 1.7016 - val_accuracy: 0.5714
# Epoch 5/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.9882 - accuracy: 0.7217 - val_loss: 1.8395 - val_accuracy: 0.4286
# Epoch 6/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.8795 - accuracy: 0.7196 - val_loss: 1.8524 - val_accuracy: 0.5714
# Epoch 7/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.5174 - accuracy: 0.8481 - val_loss: 1.8983 - val_accuracy: 0.3571
# Epoch 8/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.5881 - accuracy: 0.8333 - val_loss: 1.6101 - val_accuracy: 0.2143
# Epoch 9/20
# 32/32 [==============================] - 3s 92ms/step - loss: 0.6303 - accuracy: 0.7752 - val_loss: 1.7475 - val_accuracy: 0.5000
# Epoch 10/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.5794 - accuracy: 0.8078 - val_loss: 1.7193 - val_accuracy: 0.5714
# Epoch 11/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.2106 - accuracy: 0.9306 - val_loss: 1.5650 - val_accuracy: 0.5714
# Epoch 12/20
# 32/32 [==============================] - 3s 91ms/step - loss: 0.2880 - accuracy: 0.9165 - val_loss: 1.9500 - val_accuracy: 0.6429
# Epoch 13/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0428 - accuracy: 0.9918 - val_loss: 2.0521 - val_accuracy: 0.6429
# Epoch 14/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0947 - accuracy: 0.9696 - val_loss: 2.2514 - val_accuracy: 0.5714
# Epoch 15/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1187 - accuracy: 0.9718 - val_loss: 1.4622 - val_accuracy: 0.6429
# Epoch 16/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0109 - accuracy: 0.9993 - val_loss: 2.0693 - val_accuracy: 0.6429
# Epoch 17/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0695 - accuracy: 0.9807 - val_loss: 1.7020 - val_accuracy: 0.6429
# Epoch 18/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0354 - accuracy: 0.9910 - val_loss: 1.6071 - val_accuracy: 0.6429
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 1.6256 - val_accuracy: 0.6429
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0147 - accuracy: 0.9982 - val_loss: 2.7856 - val_accuracy: 0.5714
# 5 Fold: Accuracy of testing data = 58.33%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 95ms/step - loss: 34.0766 - accuracy: 0.1155 - val_loss: 2.2133 - val_accuracy: 0.1429
# Epoch 2/20
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0163 - accuracy: 0.2985 - val_loss: 2.0546 - val_accuracy: 0.2857
# Epoch 3/20
# 32/32 [==============================] - 3s 87ms/step - loss: 1.7116 - accuracy: 0.3867 - val_loss: 1.7002 - val_accuracy: 0.4286
# Epoch 4/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.3005 - accuracy: 0.6112 - val_loss: 1.7310 - val_accuracy: 0.2143
# Epoch 5/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.1094 - accuracy: 0.6674 - val_loss: 1.6289 - val_accuracy: 0.4286
# Epoch 6/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.9584 - accuracy: 0.6406 - val_loss: 1.1551 - val_accuracy: 0.5000
# Epoch 7/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.7476 - accuracy: 0.7894 - val_loss: 1.4226 - val_accuracy: 0.5714
# Epoch 8/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.8446 - accuracy: 0.7590 - val_loss: 1.3962 - val_accuracy: 0.4286
# Epoch 9/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.6977 - accuracy: 0.7157 - val_loss: 1.1920 - val_accuracy: 0.7143
# Epoch 10/20
# 32/32 [==============================] - 3s 87ms/step - loss: 0.3299 - accuracy: 0.8633 - val_loss: 0.9326 - val_accuracy: 0.7857
# Epoch 11/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4896 - accuracy: 0.7834 - val_loss: 0.9276 - val_accuracy: 0.6429
# Epoch 12/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4021 - accuracy: 0.8611 - val_loss: 0.9838 - val_accuracy: 0.6429
# Epoch 13/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3620 - accuracy: 0.8879 - val_loss: 0.8110 - val_accuracy: 0.6429
# Epoch 14/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1329 - accuracy: 0.9538 - val_loss: 0.7654 - val_accuracy: 0.7143
# Epoch 15/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1235 - accuracy: 0.9644 - val_loss: 0.8829 - val_accuracy: 0.7857
# Epoch 16/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0236 - accuracy: 0.9976 - val_loss: 0.5610 - val_accuracy: 0.8571
# Epoch 17/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0234 - accuracy: 0.9961 - val_loss: 0.4303 - val_accuracy: 0.8571
# Epoch 18/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0341 - accuracy: 0.9842 - val_loss: 1.2647 - val_accuracy: 0.7143
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0225 - accuracy: 0.9970 - val_loss: 0.6584 - val_accuracy: 0.8571
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0360 - accuracy: 0.9941 - val_loss: 0.7003 - val_accuracy: 0.7857
# 6 Fold: Accuracy of testing data = 55.00%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 91ms/step - loss: 44.2617 - accuracy: 0.1509 - val_loss: 2.2377 - val_accuracy: 0.2857
# Epoch 2/20
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0065 - accuracy: 0.2669 - val_loss: 2.2466 - val_accuracy: 0.3571
# Epoch 3/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.7013 - accuracy: 0.4242 - val_loss: 1.9516 - val_accuracy: 0.2857
# Epoch 4/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.3724 - accuracy: 0.5454 - val_loss: 1.6615 - val_accuracy: 0.3571
# Epoch 5/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.1172 - accuracy: 0.6437 - val_loss: 1.5588 - val_accuracy: 0.5714
# Epoch 6/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.0353 - accuracy: 0.6479 - val_loss: 1.4968 - val_accuracy: 0.3571
# Epoch 7/20
# 32/32 [==============================] - 3s 89ms/step - loss: 0.6863 - accuracy: 0.7327 - val_loss: 1.3451 - val_accuracy: 0.5714
# Epoch 8/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.5293 - accuracy: 0.8675 - val_loss: 2.0041 - val_accuracy: 0.3571
# Epoch 9/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4621 - accuracy: 0.8756 - val_loss: 1.4336 - val_accuracy: 0.5000
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4334 - accuracy: 0.8354 - val_loss: 1.4314 - val_accuracy: 0.5000
# Epoch 11/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1774 - accuracy: 0.9575 - val_loss: 2.0923 - val_accuracy: 0.3571
# Epoch 12/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3329 - accuracy: 0.8690 - val_loss: 1.9691 - val_accuracy: 0.5714
# Epoch 13/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1216 - accuracy: 0.9502 - val_loss: 1.8122 - val_accuracy: 0.4286
# Epoch 14/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1403 - accuracy: 0.9783 - val_loss: 1.4987 - val_accuracy: 0.4286
# Epoch 15/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0547 - accuracy: 0.9904 - val_loss: 1.9626 - val_accuracy: 0.5000
# Epoch 16/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0399 - accuracy: 0.9963 - val_loss: 1.7462 - val_accuracy: 0.5714
# Epoch 17/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0271 - accuracy: 0.9955 - val_loss: 1.9660 - val_accuracy: 0.4286
# Epoch 18/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0538 - accuracy: 0.9881 - val_loss: 1.9707 - val_accuracy: 0.5000
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0367 - accuracy: 0.9993 - val_loss: 1.8916 - val_accuracy: 0.6429
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0273 - accuracy: 0.9938 - val_loss: 1.6694 - val_accuracy: 0.5000
# 7 Fold: Accuracy of testing data = 55.00%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 91ms/step - loss: 33.0027 - accuracy: 0.1501 - val_loss: 2.3684 - val_accuracy: 0.2143
# Epoch 2/20
# 32/32 [==============================] - 3s 91ms/step - loss: 2.0011 - accuracy: 0.2739 - val_loss: 2.0545 - val_accuracy: 0.2857
# Epoch 3/20
# 32/32 [==============================] - 3s 93ms/step - loss: 1.8445 - accuracy: 0.3675 - val_loss: 2.1423 - val_accuracy: 0.1429
# Epoch 4/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.5281 - accuracy: 0.4092 - val_loss: 2.5899 - val_accuracy: 0.2857
# Epoch 5/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.4444 - accuracy: 0.5321 - val_loss: 1.9878 - val_accuracy: 0.4286
# Epoch 6/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.0109 - accuracy: 0.6632 - val_loss: 1.8166 - val_accuracy: 0.4286
# Epoch 7/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.7127 - accuracy: 0.8051 - val_loss: 1.6852 - val_accuracy: 0.4286
# Epoch 8/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.6223 - accuracy: 0.8197 - val_loss: 1.5844 - val_accuracy: 0.5000
# Epoch 9/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.3766 - accuracy: 0.8858 - val_loss: 1.7154 - val_accuracy: 0.4286
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2583 - accuracy: 0.8874 - val_loss: 1.5622 - val_accuracy: 0.5000
# Epoch 11/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3517 - accuracy: 0.9250 - val_loss: 1.4374 - val_accuracy: 0.5714
# Epoch 12/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4201 - accuracy: 0.8920 - val_loss: 1.4498 - val_accuracy: 0.5714
# Epoch 13/20
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1010 - accuracy: 0.9878 - val_loss: 2.3110 - val_accuracy: 0.4286
# Epoch 14/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.2859 - accuracy: 0.9436 - val_loss: 1.4709 - val_accuracy: 0.5000
# Epoch 15/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1215 - accuracy: 0.9717 - val_loss: 1.6812 - val_accuracy: 0.6429
# Epoch 16/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.0498 - accuracy: 0.9853 - val_loss: 2.2514 - val_accuracy: 0.5714
# Epoch 17/20
# 32/32 [==============================] - 3s 87ms/step - loss: 0.0804 - accuracy: 0.9745 - val_loss: 1.5666 - val_accuracy: 0.6429
# Epoch 18/20
# 32/32 [==============================] - 3s 87ms/step - loss: 0.0512 - accuracy: 0.9800 - val_loss: 1.6595 - val_accuracy: 0.4286
# Epoch 19/20
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1974 - accuracy: 0.9504 - val_loss: 3.4752 - val_accuracy: 0.3571
# Epoch 20/20
# 32/32 [==============================] - 3s 89ms/step - loss: 0.4516 - accuracy: 0.9024 - val_loss: 1.8544 - val_accuracy: 0.4286
# 8 Fold: Accuracy of testing data = 60.00%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 91ms/step - loss: 29.5471 - accuracy: 0.0661 - val_loss: 2.2925 - val_accuracy: 0.2143
# Epoch 2/20
# 32/32 [==============================] - 3s 87ms/step - loss: 2.1329 - accuracy: 0.2512 - val_loss: 1.9198 - val_accuracy: 0.2857
# Epoch 3/20
# 32/32 [==============================] - 3s 90ms/step - loss: 1.8528 - accuracy: 0.3700 - val_loss: 1.9548 - val_accuracy: 0.2857
# Epoch 4/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.3080 - accuracy: 0.5862 - val_loss: 1.9267 - val_accuracy: 0.2857
# Epoch 5/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.9958 - accuracy: 0.6407 - val_loss: 1.5455 - val_accuracy: 0.3571
# Epoch 6/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.6055 - accuracy: 0.7995 - val_loss: 2.0109 - val_accuracy: 0.5000
# Epoch 7/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.5703 - accuracy: 0.7889 - val_loss: 1.8144 - val_accuracy: 0.3571
# Epoch 8/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2568 - accuracy: 0.9042 - val_loss: 2.4281 - val_accuracy: 0.4286
# Epoch 9/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.2005 - accuracy: 0.9636 - val_loss: 2.4089 - val_accuracy: 0.3571
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1989 - accuracy: 0.9398 - val_loss: 2.1761 - val_accuracy: 0.5000
# Epoch 11/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0466 - accuracy: 0.9805 - val_loss: 1.8448 - val_accuracy: 0.5000
# Epoch 12/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 2.1409 - val_accuracy: 0.4286
# Epoch 13/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.2820 - val_accuracy: 0.4286
# Epoch 14/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.3498 - val_accuracy: 0.5000
# Epoch 15/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3527 - val_accuracy: 0.4286
# Epoch 16/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.3856 - val_accuracy: 0.4286
# Epoch 17/20
# 32/32 [==============================] - 3s 85ms/step - loss: 6.5755e-04 - accuracy: 1.0000 - val_loss: 2.3175 - val_accuracy: 0.5000
# Epoch 18/20
# 32/32 [==============================] - 3s 85ms/step - loss: 5.2278e-04 - accuracy: 1.0000 - val_loss: 2.4090 - val_accuracy: 0.5000
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 3.4893e-04 - accuracy: 1.0000 - val_loss: 2.4485 - val_accuracy: 0.5000
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 2.9499e-04 - accuracy: 1.0000 - val_loss: 2.4125 - val_accuracy: 0.4286
# 9 Fold: Accuracy of testing data = 40.00%
#
# Epoch 1/20
# 32/32 [==============================] - 4s 91ms/step - loss: 40.2836 - accuracy: 0.1510 - val_loss: 2.2719 - val_accuracy: 0.1429
# Epoch 2/20
# 32/32 [==============================] - 3s 86ms/step - loss: 2.2125 - accuracy: 0.2415 - val_loss: 1.9554 - val_accuracy: 0.2857
# Epoch 3/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.8062 - accuracy: 0.3646 - val_loss: 1.9378 - val_accuracy: 0.2857
# Epoch 4/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.5231 - accuracy: 0.5080 - val_loss: 1.6551 - val_accuracy: 0.4286
# Epoch 5/20
# 32/32 [==============================] - 3s 84ms/step - loss: 1.3199 - accuracy: 0.5481 - val_loss: 1.3779 - val_accuracy: 0.4286
# Epoch 6/20
# 32/32 [==============================] - 3s 85ms/step - loss: 1.1151 - accuracy: 0.7041 - val_loss: 1.3392 - val_accuracy: 0.5714
# Epoch 7/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.8856 - accuracy: 0.7220 - val_loss: 0.9098 - val_accuracy: 0.7857
# Epoch 8/20
# 32/32 [==============================] - 3s 87ms/step - loss: 0.5943 - accuracy: 0.8433 - val_loss: 1.3762 - val_accuracy: 0.4286
# Epoch 9/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.6337 - accuracy: 0.7035 - val_loss: 1.0485 - val_accuracy: 0.5000
# Epoch 10/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.4783 - accuracy: 0.8607 - val_loss: 1.4376 - val_accuracy: 0.5000
# Epoch 11/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.4750 - accuracy: 0.8345 - val_loss: 0.9798 - val_accuracy: 0.7143
# Epoch 12/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3395 - accuracy: 0.8929 - val_loss: 1.1845 - val_accuracy: 0.5714
# Epoch 13/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1607 - accuracy: 0.9632 - val_loss: 1.2963 - val_accuracy: 0.5000
# Epoch 14/20
# 32/32 [==============================] - 3s 88ms/step - loss: 0.1660 - accuracy: 0.9609 - val_loss: 1.1147 - val_accuracy: 0.6429
# Epoch 15/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1041 - accuracy: 0.9509 - val_loss: 1.2807 - val_accuracy: 0.7143
# Epoch 16/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3677 - accuracy: 0.8970 - val_loss: 0.7644 - val_accuracy: 0.7143
# Epoch 17/20
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1921 - accuracy: 0.9477 - val_loss: 0.8657 - val_accuracy: 0.7143
# Epoch 18/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1217 - accuracy: 0.9752 - val_loss: 0.8456 - val_accuracy: 0.7857
# Epoch 19/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1408 - accuracy: 0.9472 - val_loss: 0.9195 - val_accuracy: 0.5714
# Epoch 20/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0690 - accuracy: 0.9829 - val_loss: 0.7127 - val_accuracy: 0.7143
# 10 Fold: Accuracy of testing data = 60.00%

# %%
print("validation accuracy: ",VALIDATION_ACCURACY)
print("validation loss: ", VALIDATION_LOSS)
print("test accuracy: ",TEST_ACCURACY)
# Out:
# validation accuracy:  [0.6428571343421936, 0.7142857313156128, 0.7142857313156128, 0.5714285969734192, 0.6428571343421936, 0.8571428656578064, 0.6428571343421936, 0.6428571343421936, 0.5, 0.7857142686843872]
# validation loss:  [1.689204454421997, 1.0924993753433228, 1.5541772842407227, 1.40695321559906, 1.9499750137329102, 0.5610189437866211, 1.8916231393814087, 1.68119215965271, 2.01088547706604, 0.9097792506217957]
# test accuracy:  [61.666667461395264, 60.00000238418579, 63.333332538604736, 41.66666567325592, 58.33333134651184, 55.000001192092896, 55.000001192092896, 60.00000238418579, 40.00000059604645, 60.00000238418579]

# %%
print("average validation accuracy: ",sum(VALIDATION_ACCURACY)/len(VALIDATION_ACCURACY))
print("average test accuracy: ",sum(TEST_ACCURACY)/len(TEST_ACCURACY))
# Out:
# average validation accuracy:  0.6714285731315612
# average test accuracy:  55.50000071525574
